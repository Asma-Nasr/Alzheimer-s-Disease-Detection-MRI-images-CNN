# %% [markdown]
# ## Necessary Modules

# %%
from preprocessing import ImagePreprocessor
from utils import display_image

# %%
preprocessor = ImagePreprocessor(input_dir='', output_dir='processed')
result = preprocessor.process_image('181.jpg', method='crop',tol=8)

# %% [markdown]
# ## Original Image

# %%
display_image('181.jpg')

# %% [markdown]
# ## Processed Image

# %%
display_image('processed/181.jpg')
