# %% [markdown]
# ## Necessary Modules

# %%
from dcm2jpg import dicom_to_jpg
from utils import display_image

# %% [markdown]
# ## Sample Image
# - [Sample Image - DEMO Mrbrain](https://rubomedical.com/dicom_files/index.html)

# %%
dicom_path = 'data/MRBRAIN.DCM'
output_folder = 'out'

# %%
dicom_to_jpg(dicom_path,output_folder)
# Out:
# Success: data/MRBRAIN.DCM → out\MRBRAIN.jpg

# %% [markdown]
# ## Resulting Image

# %%
display_image('out\MRBRAIN.jpg')
