# %% [markdown]
# ## Necessary modules

# %%
from preprocessing import ImagePreprocessor
from utils import display_image

# %%
preprocessor = ImagePreprocessor(input_dir='', output_dir='processed')
result = preprocessor.process_image('18.jpg', method='trim')

# %% [markdown]
# ## Original Image

# %%
display_image('18.jpg')

# %% [markdown]
# ## Processed Imaage

# %%
display_image('processed/18.jpg')
